# %%
'''
Reto 1 — Cargar y validar el archivo
Solicitud del líder de datos:
“Necesitamos confirmar que el archivo recibido del área comercial puede ser procesado por el sistema.”

Objetivo:
Leer el archivo CSV y generar una validación inicial.
Debes entregar:
cantidad total de filas
cantidad total de columnas
nombres de las columnas
tipo de dato detectado por columna
cantidad de valores nulos por columna
Regla de negocio:
El resultado debe permitir decidir si el archivo puede continuar a la etapa de transformación.

'''
# Out:
#   Cell In[1], line 18
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
ruta = r'C:\Users\Javier\OneDrive - Oracle Corporation\PYTHON\muestra_datos.csv' #de esta forma leo un archivo con pandas
df = pd.read_csv(ruta)
print(df.columns) # obtengo los nombres de columna
# Out:
# Index(['cedula', 'nombre', 'apellido', 'direccion', 'ciudad', 'banco',
#        'numero_cuenta', 'tipo_cuenta', 'saldo', 'fecha_apertura'],
#       dtype='object')
