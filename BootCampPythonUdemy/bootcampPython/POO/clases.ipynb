# %%
# Ejemplo de la primera clase en python
class CuentaBancaria:
    def __init__(self,numero,titular,saldo,moneda,tipo,cuenta,estado):
        self.numero = numero
        self.titular = titular
        self.__saldo = saldo
        self.moneda = moneda
        self.tipo = tipo
        self.__cuenta = cuenta
        self.estado = estado


if __name__ == '__main__':
    print(CuentaBancaria.numero)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 14
#      10         self.estado = estado
#      13 if __name__ == '__main__':
# ---> 14     print(CuentaBancaria.numero)
#
# AttributeError: type object 'CuentaBancaria' has no attribute 'numero'
