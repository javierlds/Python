# %%
lista_nombres = ['javier','jose','juan','maria','carolina','lina','marcela']
print(lista_nombres)

#recorrer una lista 
for lista in lista_nombres:
    print(lista)

longitud = len(lista_nombres)
print(longitud)
orden = sorted(lista_nombres)
print(orden)
# Out:
# ['javier', 'jose', 'juan', 'maria', 'carolina', 'lina', 'marcela']
# javier
# jose
# juan
# maria
# carolina
# lina
# marcela
# 7
# ['carolina', 'javier', 'jose', 'juan', 'lina', 'marcela', 'maria']
