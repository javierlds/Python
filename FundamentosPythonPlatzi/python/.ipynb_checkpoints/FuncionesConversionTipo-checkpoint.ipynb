# %%
# Conversion tipo
def conversionint():

def conversionfloat():

def conversion 

print(3.14, int(3.14))  # la conversion deja el numero entero, quita todo lo que este despues del punto.
print("3.156", int)

if __name__ == '__main__':
    try:
        menu = """
        1. Conversion Int
        2. Conversion Float
        3. Conversion String """

        numero = int(input("ingrese numero a convertir"))
        if menu ==1:
            conversionint(numero)
        elif menu ==2:
            conversionfloat(numero)

    except ValueError: 
        print("Debe ingresar un numero valido")
# Out:
# 3.14 3
