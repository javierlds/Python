# %%
# Sentencia AND
a = 1
b = 2

if a<10 and b ==2:
    print("esto es verdadero")
# Out:
# esto es verdadero

# %%
def operadorAnd(numero1, numero2):
    if numero1 == 7 and numero2 == 14:
        print('validacion de numeros ')
    

def operadorOr(numero3, numero4):
    if numero3 == 3 or numero3 == 6:
        print('validacion de 3 o 6')

def operadorNot(numero5, numero6):
    if not(numero5 == 5):
        print('no es numero 5')
        

    

if __name__ == '__main__':
    opcion =  int(input('Ingrese 1 operador1, Ingrese 2 operador 2, Ingrese 2 operador 3'))
    if opcion == 1:
        operadorAnd(2,3)
    elif opcion == 2:
        operadorOr(4,6)
    else:
        operadorNot(3,8)
# Out:
# Ingrese 1 operador1, Ingrese 2 operador 2, Ingrese 2 operador 3 3
# no es numero 5
