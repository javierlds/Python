# %%
import platform
import os

sistema = platform.system()
version = platform.version()
directorio = os.getcwd()

print('sistema: ', str(sistema))
print('version: ',version)
print('directorio:',directorio)
print(f'Sistema {sistema} con version {version} y directorio: {directorio}')
# Out:
# sistema:  Windows
# version:  10.0.26100
# directorio: C:\Users\Javier\Documents\Python\FundamentosPythonPlatzi\python
# Sistema Windows con version 10.0.26100 y directorio: C:\Users\Javier\Documents\Python\FundamentosPythonPlatzi\python
